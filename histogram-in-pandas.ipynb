# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
mu = 168
sigma = 5
sample = 250
np.random.seed(0)
height_f = np.random.normal(mu, sigma, sample).astype(int)

# %%
print(np.ptp(height_f))
# Out:
# 24

# %%
mu = 176 #mean
sigma = 6 #stddev
sample = 250
np.random.seed(1)
height_m = np.random.normal(mu, sigma, sample).astype(int)

# %%
gym = pd.DataFrame({'height_m':height_m, 'height_f':height_f})

# %%
gym
# Out:
#      height_m  height_f
# 0         185       176
# 1         172       170
# 2         172       172
# 3         169       179
# 4         181       177
# ..        ...       ...
# 245       180       159
# 246       179       173
# 247       173       173
# 248       186       163
# 249       168       160
#
# [250 rows x 2 columns]

# %%
plt.figure(dpi=1200)
gym.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
gym.groupby('height_m').count()
gym.groupby('height_f').count()
gym.plot.hist(bins=20, alpha = 0.7)
# Out:
# <AxesSubplot:ylabel='Frequency'>
