# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import scipy

# %%
df = pd.read_csv("nifty-data.csv")
df.head()
# Out:
#         Date     Close
# 0  02-Mar-20  11132.75
# 1  03-Mar-20  11303.30
# 2  04-Mar-20  11251.00
# 3  05-Mar-20  11269.00
# 4  06-Mar-20  10989.45

# %%
#df.index = df['Date']

# %%
df.head()
# Out:
#         Date     Close
# 0  02-Mar-20  11132.75
# 1  03-Mar-20  11303.30
# 2  04-Mar-20  11251.00
# 3  05-Mar-20  11269.00
# 4  06-Mar-20  10989.45

# %%
df['Close'].plot(figsize = (12,6))
plt.show()

# %%
df['Close'].plot(figsize=(12,6))
plt.xlim([0,50])
plt.show()

# %%
ind = df.index[df['Date']=='19-May-20'].tolist()
print(ind)
# Out:
# [50]
